# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cmap = plt.get_cmap("tab10")

# %% [markdown]
# ## MIMIC

# %% [markdown]
# <!-- # mimic4_ce_Dyna   = [0.5334,0.6016,0.7713,0.9435,1.0054,1.0098,0.8295]
# # mimic4_ce_Extr   = [0.8750,0.8312,0.7856,0.7652,0.7529,0.7414,0.7168]
# # ###################################################
# # mimic4_comp_Dyna = [0.0871,0.1480,0.2612,0.3465,0.3695,0.3712,0.3073]
# # mimic4_comp_Extr = [0.3179,0.3038,0.2889,0.2833,0.2779,0.2733,0.2621]
# # ###################################################
# # mimic4_suff_Dyna = [0.0658 ,0.0082,-0.0649,-0.0950,-0.1061,-0.1079,-0.1010]
# # mimic4_suff_Extr = [-0.0923,-0.0607,-0.0249,-0.0097,-0.0028,0.0012,0.0053] -->

# %%
mimic4_ce_Dyna_mean   = [0.4740,0.6650,0.8099,0.9055,1.0325,1.1015]
mimic4_ce_Dyna_stdd   = [0.0109,0.0107,0.0102,0.0103,0.0115,0.0138]                     
mimic4_ce_Extr_mean   = [0.8144,0.9346,1.0659,1.1464,1.2021,1.2410]
mimic4_ce_Extr_stdd   = [0.0126,0.0117,0.0133,0.0160,0.0174,0.0187]

###################################################
mimic4_comp_Dyna_mean = [0.0370,0.0880,0.1630,0.2138,0.2433,0.2480]
mimic4_comp_Dyna_stdd = [0.0023,0.0029,0.0030,0.0041,0.0044,0.0046]
mimic4_comp_Extr_mean = [0.2349,0.2809,0.3142,0.3281,0.3355,0.3400]
mimic4_comp_Extr_stdd = [0.0031,0.0037,0.0033,0.0046,0.0052,0.0060]
###################################################
mimic4_suff_Dyna_mean = [0.2169,0.1571,0.0743,0.0272,0.0122,0.0096]
mimic4_suff_Dyna_stdd = [0.0029,0.0032,0.0034,0.0031,0.0029,0.0026]
mimic4_suff_Extr_mean = [0.1045,0.0611,0.011,-0.0044,-0.0077,-0.0097]
mimic4_suff_Extr_stdd = [0.0022,0.0025,0.0030,0.0035,0.0023,0.0021]

# %%
# X-axis values
x_values = x_ticks = [5, 10, 20, 30, 40, 50]

fig, axes = plt.subplots(1, 3, figsize=(24, 8))
# Colors for the lines
# colors = sns.color_palette("tab10", 2)
colors = [cmap.colors[4], cmap.colors[5]]

# Common style settings
for ax in axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', which='major', labelsize=16)
    sns.despine(ax=ax, left=True, bottom=True)

# Plot 1: CE

axes[0].errorbar(x_values, mimic4_ce_Dyna_mean, yerr=mimic4_ce_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=2.5, markersize=10)
axes[0].errorbar(x_values, mimic4_ce_Extr_mean, yerr=mimic4_ce_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=2.5, markersize=10)
axes[0].set_title('CrossEntropy', fontsize=28, 
                  # fontweight='bold'
                 )
axes[0].set_xlabel('Top K - % Perturbation', fontsize=24)
# axes[0].set_ylabel('CrossEntropy', fontsize=20)
axes[0].legend(title='Method', fontsize=24, title_fontsize=24, loc='best')
# axes[0].set_xticklabels(axes[0].get_xticklabels(), fontsize=20)
axes[0].set_xticks(axes[0].get_xticks())  # Explicitly set current tick positions
axes[0].set_xticklabels(axes[0].get_xticklabels(), fontsize=20)
# axes[0].set_ylabel("")  # No y-axis label
axes[0].set_yticks(axes[0].get_yticks())  # Explicitly set current tick positions
axes[0].set_yticklabels(axes[0].get_yticklabels(), fontsize=20)
axes[0].set_xticks(x_ticks)
axes[0].set_ylim(0.4,1.3)
axes[0].grid(linestyle='--')

# Plot 2: Comp
# axes[1].plot(x_values, mimic4_comp_Dyna[:-1], marker='o', label='DynaMask', color=colors[0], linewidth=2.5, markersize=10)
# axes[1].plot(x_values, mimic4_comp_Extr[:-1], marker='s', label='ExtremalMask', color=colors[1], linewidth=2.5, markersize=10)
axes[1].errorbar(x_values, mimic4_comp_Dyna_mean, yerr=mimic4_comp_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=2.5, markersize=10)
axes[1].errorbar(x_values, mimic4_comp_Extr_mean, yerr=mimic4_comp_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=2.5, markersize=10)
axes[1].set_title('Comprehensiveness', fontsize=28, 
                  # fontweight='bold'
                 )
axes[1].set_xlabel('Top K - % Perturbation', fontsize=24)
# axes[1].set_ylabel('Comprehensiveness', fontsize=20)
axes[1].legend(title='Method', fontsize=24, title_fontsize=24, loc='best')
axes[1].set_xticks(x_ticks)
axes[1].set_xticklabels(axes[1].get_xticklabels(), fontsize=20)
# axes[1].set_ylabel("")  # No y-axis label
axes[1].set_yticks(axes[1].get_yticks())  # Explicitly set current tick positions
axes[1].set_yticklabels(axes[1].get_yticklabels(), fontsize=20)
axes[1].set_ylim(-0.1,0.5)
axes[1].grid(linestyle='--')

# Plot 3: Suff
# axes[2].plot(x_values, mimic4_suff_Dyna[:-1], marker='o', label='DynaMask', color=colors[0], linewidth=2.5, markersize=10)
# axes[2].plot(x_values, mimic4_suff_Extr[:-1], marker='s', label='ExtremalMask', color=colors[1], linewidth=2.5, markersize=10)
axes[2].errorbar(x_values, mimic4_suff_Dyna_mean, yerr=mimic4_suff_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=3, markersize=10)
axes[2].errorbar(x_values, mimic4_suff_Extr_mean, yerr=mimic4_suff_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=3, markersize=10)
axes[2].set_title('Sufficiency', fontsize=28, 
                  # fontweight='bold'
                 )
axes[2].set_xlabel('Top K - % Perturbation', fontsize=24)
# axes[2].set_ylabel('Sufficiency', fontsize=24)
axes[2].legend(title='Method', fontsize=24, title_fontsize=24, loc='best')
axes[2].set_xticks(x_ticks)
axes[2].set_xticklabels(axes[2].get_xticklabels(), fontsize=20)
axes[2].set_ylabel("")  # No y-axis label
axes[2].set_yticks(axes[2].get_yticks())  # Explicitly set current tick positions
axes[2].set_yticklabels(axes[2].get_yticklabels(), fontsize=20)
axes[2].set_ylim(-0.02,0.25)
axes[2].grid(linestyle='--')

# Adjust layout
plt.tight_layout()
plt.subplots_adjust(wspace=0.3)
plt.show()
# plt.savefig('xai_metrics_mimic4.png', dpi=600, bbox_inches='tight', pad_inches=0.1)

# %%
# # X-axis values
# x_values = x_ticks = [5, 10, 20, 30, 40, 50]


# fig, axes = plt.subplots(1, 3, figsize=(24, 8))
# # Colors for the lines
# # colors = sns.color_palette("tab10", 2)
# colors = [cmap.colors[4], cmap.colors[5]]

# # Common style settings
# for ax in axes:
#     ax.spines['top'].set_visible(False)
#     ax.spines['right'].set_visible(False)
#     ax.spines['left'].set_visible(False)
#     ax.spines['bottom'].set_visible(False)
#     ax.tick_params(axis='both', which='major', labelsize=16)
#     sns.despine(ax=ax, left=True, bottom=True)

# # Plot 1: CE
# # axes[0].plot(x_values, mimic4_ce_Dyna[:-1], marker='o', label='DynaMask', color=colors[0], linewidth=2.5, markersize=10)
# # axes[0].plot(x_values, mimic4_ce_Extr[:-1], marker='s', label='ExtremalMask', color=colors[1], linewidth=2.5, markersize=10)
# axes[0].errorbar(x_values, mimic4_ce_Dyna_mean, yerr=mimic4_ce_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=2.5, markersize=10)
# axes[0].errorbar(x_values, mimic4_ce_Extr_mean, yerr=mimic4_ce_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=2.5, markersize=10)
# axes[0].set_title('CrossEntropy', fontsize=24, fontweight='bold')
# axes[0].set_xlabel('Top K - % Perturbation', fontsize=20)
# axes[0].set_ylabel('CrossEntropy', fontsize=20)
# axes[0].legend(title='Method', fontsize=16, title_fontsize='18', loc='best')
# axes[0].set_xticks(x_ticks)
# axes[0].set_ylim(0.4,1.3)
# axes[0].grid(linestyle='--')

# # Plot 2: Comp
# # axes[1].plot(x_values, mimic4_comp_Dyna[:-1], marker='o', label='DynaMask', color=colors[0], linewidth=2.5, markersize=10)
# # axes[1].plot(x_values, mimic4_comp_Extr[:-1], marker='s', label='ExtremalMask', color=colors[1], linewidth=2.5, markersize=10)
# axes[1].errorbar(x_values, mimic4_comp_Dyna_mean, yerr=mimic4_comp_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=2.5, markersize=10)
# axes[1].errorbar(x_values, mimic4_comp_Extr_mean, yerr=mimic4_comp_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=2.5, markersize=10)
# axes[1].set_title('Comprehensiveness', fontsize=24, fontweight='bold')
# axes[1].set_xlabel('Top K - % Perturbation', fontsize=20)
# axes[1].set_ylabel('Comprehensiveness', fontsize=20)
# axes[1].legend(title='Method', fontsize=16, title_fontsize='18', loc='best')
# axes[1].set_xticks(x_ticks)
# axes[1].set_ylim(-0.1,0.5)
# axes[1].grid(linestyle='--')

# # Plot 3: Suff
# # axes[2].plot(x_values, mimic4_suff_Dyna[:-1], marker='o', label='DynaMask', color=colors[0], linewidth=2.5, markersize=10)
# # axes[2].plot(x_values, mimic4_suff_Extr[:-1], marker='s', label='ExtremalMask', color=colors[1], linewidth=2.5, markersize=10)
# axes[2].errorbar(x_values, mimic4_suff_Dyna_mean, yerr=mimic4_suff_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=2.5, markersize=10)
# axes[2].errorbar(x_values, mimic4_suff_Extr_mean, yerr=mimic4_suff_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=2.5, markersize=10)
# axes[2].set_title('Sufficiency', fontsize=24, fontweight='bold')
# axes[2].set_xlabel('Top K - % Perturbation', fontsize=20)
# axes[2].set_ylabel('Sufficiency', fontsize=20)
# axes[2].legend(title='Method', fontsize=16, title_fontsize='18', loc='best')
# axes[2].set_xticks(x_ticks)
# axes[2].set_ylim(-0.10,0.25)
# axes[2].grid(linestyle='--')

# # Adjust layout
# plt.tight_layout()
# plt.subplots_adjust(wspace=0.3)
# plt.show()
# # plt.savefig('xai_metrics_mimic.png', dpi=600, bbox_inches='tight', pad_inches=0.1)

# %% [markdown]
# # eiCU

# %% [markdown]
# <!-- eicu_ce_Dyna   = [0.5968,0.6143,0.6664,0.7535,0.8093,0.8184,0.7800]
# eicu_ce_Extr   = [0.7357,0.7560,0.7695,0.7721,0.7749,0.7762,0.8125]
# ###################################################
# eicu_comp_Dyna = [0.0768,0.1020,0.1566,0.2234,0.2583,0.2626,0.2329]
# eicu_comp_Extr = [0.2064,0.2192,0.2258,0.2271,0.2284,0.2291,0.2343]
# ###################################################
# eicu_suff_Dyna = [-0.0510,-0.00837,-0.1269,-0.1551,-0.1654,-0.1675,-0.1014]
# eicu_suff_Extr = [-0.1241,-0.1005,-0.0925,-0.0916,-0.0911,-0.0906,-0.0620] -->

# %%
eicu_ce_Dyna_mean   = [0.6102,0.6249,0.6687,0.7432,0.7914,0.7990]
eicu_ce_Dyna_stdd   = [0.0190,0.0150,0.0134,0.0145,0.0252,0.0274]                     
eicu_ce_Extr_mean   = [0.6964,0.7237,0.7548,0.7975,0.8325,0.8410]
eicu_ce_Extr_stdd   = [0.0131,0.0173,0.0207,0.0207,0.0214,0.0215]

###################################################
eicu_comp_Dyna_mean = [0.0682,0.0902,0.1380,0.1972,0.2285,0.2326]
eicu_comp_Dyna_stdd = [0.0123,0.0167,0.0164,0.0171,0.0121,0.0125]
eicu_comp_Extr_mean = [0.1431,0.1757,0.2022,0.2236,0.2446,0.2555]
eicu_comp_Extr_stdd = [0.0130,0.0132,0.0135,0.0132,0.0135,0.0133]
###################################################
eicu_suff_Dyna_mean = [-0.0328,-0.0621,-0.1012,-0.1263,-0.1356,-0.1377]
eicu_suff_Dyna_stdd = [0.00257,0.00306,0.00364,0.00408,0.00421,0.00422]
eicu_suff_Extr_mean = [-0.1086,-0.1217,-0.1367,-0.1420,-0.1456,-0.1456]
eicu_suff_Extr_stdd = [0.00360,0.00266,0.00223,0.00220,0.00220,0.00223]

# %%
# X-axis values
x_values = x_ticks = [5, 10, 20, 30, 40, 50]

fig, axes = plt.subplots(1, 3, figsize=(24, 8))
# Colors for the lines
# colors = sns.color_palette("tab10", 2)
colors = [cmap.colors[4], cmap.colors[5]]

# Common style settings
for ax in axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', which='major', labelsize=16)
    sns.despine(ax=ax, left=True, bottom=True)

# Plot 1: CE

axes[0].errorbar(x_values, eicu_ce_Dyna_mean, yerr=eicu_ce_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=2.5, markersize=10)
axes[0].errorbar(x_values, eicu_ce_Extr_mean, yerr=eicu_ce_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=2.5, markersize=10)
axes[0].set_title('CrossEntropy', fontsize=28, 
                  # fontweight='bold'
                 )
axes[0].set_xlabel('Top K - % Perturbation', fontsize=24)
# axes[0].set_ylabel('CrossEntropy', fontsize=20)
axes[0].legend(title='Method', fontsize=24, title_fontsize=24, loc='best')
# axes[0].set_xticklabels(axes[0].get_xticklabels(), fontsize=20)
axes[0].set_xticks(axes[0].get_xticks())  # Explicitly set current tick positions
axes[0].set_xticklabels(axes[0].get_xticklabels(), fontsize=20)
# axes[0].set_ylabel("")  # No y-axis label
axes[0].set_yticks(axes[0].get_yticks())  # Explicitly set current tick positions
axes[0].set_yticklabels(axes[0].get_yticklabels(), fontsize=20)
axes[0].set_xticks(x_ticks)
axes[0].set_ylim(0.55,0.9)
axes[0].grid(linestyle='--')

# Plot 2: Comp
# axes[1].plot(x_values, eicu_comp_Dyna[:-1], marker='o', label='DynaMask', color=colors[0], linewidth=2.5, markersize=10)
# axes[1].plot(x_values, eicu_comp_Extr[:-1], marker='s', label='ExtremalMask', color=colors[1], linewidth=2.5, markersize=10)
axes[1].errorbar(x_values, eicu_comp_Dyna_mean, yerr=eicu_comp_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=2.5, markersize=10)
axes[1].errorbar(x_values, eicu_comp_Extr_mean, yerr=eicu_comp_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=2.5, markersize=10)
axes[1].set_title('Comprehensiveness', fontsize=28, 
                  # fontweight='bold'
                 )
axes[1].set_xlabel('Top K - % Perturbation', fontsize=24)
# axes[1].set_ylabel('Comprehensiveness', fontsize=20)
axes[1].legend(title='Method', fontsize=24, title_fontsize=24, loc='best')
axes[1].set_xticks(x_ticks)
axes[1].set_xticklabels(axes[1].get_xticklabels(), fontsize=20)
# axes[1].set_ylabel("")  # No y-axis label
axes[1].set_yticks(axes[1].get_yticks())  # Explicitly set current tick positions
axes[1].set_yticklabels(axes[1].get_yticklabels(), fontsize=20)
axes[1].set_ylim(0.05,0.3)
axes[1].grid(linestyle='--')

# Plot 3: Suff
# axes[2].plot(x_values, eicu_suff_Dyna[:-1], marker='o', label='DynaMask', color=colors[0], linewidth=2.5, markersize=10)
# axes[2].plot(x_values, eicu_suff_Extr[:-1], marker='s', label='ExtremalMask', color=colors[1], linewidth=2.5, markersize=10)
axes[2].errorbar(x_values, eicu_suff_Dyna_mean, yerr=eicu_suff_Dyna_stdd, fmt='o-', color=colors[0],   label='DynaMask', capsize=5, linewidth=3, markersize=10)
axes[2].errorbar(x_values, eicu_suff_Extr_mean, yerr=eicu_suff_Extr_stdd, fmt='s-', color=colors[1],   label='ExtremalMask', capsize=5, linewidth=3, markersize=10)
axes[2].set_title('Sufficiency', fontsize=28, 
                  # fontweight='bold'
                 )
axes[2].set_xlabel('Top K - % Perturbation', fontsize=24)
# axes[2].set_ylabel('Sufficiency', fontsize=24)
axes[2].legend(title='Method', fontsize=24, title_fontsize=24, loc='best')
axes[2].set_xticks(x_ticks)
axes[2].set_xticklabels(axes[2].get_xticklabels(), fontsize=20)
axes[2].set_ylabel("")  # No y-axis label
axes[2].set_yticks(axes[2].get_yticks())  # Explicitly set current tick positions
axes[2].set_yticklabels(axes[2].get_yticklabels(), fontsize=20)
axes[2].set_ylim(-0.16,0.0)
axes[2].grid(linestyle='--')

# Adjust layout
plt.tight_layout()
plt.subplots_adjust(wspace=0.3)
plt.show()
# plt.savefig('xai_metrics_eicu.png', dpi=600, bbox_inches='tight', pad_inches=0.1)
